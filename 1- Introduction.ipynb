# %% [markdown]
# Add Library

# %%
# %pip install nltk

# %%
import numpy as np # for array
import  pandas as pd # for dataframe
import matplotlib.pyplot as plt #Visualizing
# import seaborn # for plot
#import sklearn # for  Machine learning
#import nltk # for text Minnig 
#import math # for Mathematical Functions

# %% [markdown]
# Variable Explorer

# %%
print("Hello World")

#Variaable Explorer
a=3
b="s"
c=True
d=2*4.5
e=[]
f=[2,'s',True]
# Out:
# Hello World

# %% [markdown]
# Array

# %%
g=np.array([1,2,True])
# این آرایه نمیفهمه مدلها مختلف داده رو. میاد همه رو به یکی تبدیل میکنه بنا به اولویتش. که استرینگ و عدد هست، همه رو تبدیل میکنه
g

# %% [markdown]
# DataFrame

# %%
h=pd.DataFrame({"C1":[1,2,3],"C2":["a",4,5]})
h.iloc[0:2,:]
h.loc[:,"C1"]
h["C1"]

# %%
message = "helloworld"
print (message)

# %%
import os
os.getcwd()

# %%
import sys
print(sys.version)

# %%
import numpy
import scipy
import matplotlib
import pandas
